# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from pathlib import Path
import seaborn as sns

print("🎯 DAY 1 - PhD Week 1: Data Loader Development")
print("=" * 60)
print("Objective: Create unified data loading system starting with FD001")
print("Time allocated: 4 hours")
print("Deliverable: Working data_loader.py with FD001 support")

# =============================================================================
# HOUR 1: UNDERSTANDING DATA LOADERS & EXPLORING FD001
# =============================================================================

print("\n📚 HOUR 1: Understanding Data Loaders & FD001 Structure")
print("-" * 50)

print("""
🔍 WHAT IS A DATA LOADER?

A data loader is your gateway between raw data files and ML models. Think of it as:
- 📚 A librarian who organizes messy books (data files) 
- 🔄 A translator that converts raw formats into clean pandas DataFrames
- 🎯 A standardized interface that works across different datasets

Key responsibilities:
1. Read various file formats (.txt, .csv, .mat, etc.)
2. Handle different data structures consistently  
3. Validate data quality and integrity
4. Provide easy access to train/test splits
5. Enable seamless switching between datasets
""")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import os
#       5 from pathlib import Path
# ----> 6 import seaborn as sns
#       8 print("🎯 DAY 1 - PhD Week 1: Data Loader Development")
#       9 print("=" * 60)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\phd-pdm\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !where python   # Windows
# Out:
# C:\Users\DELL\anaconda3\envs\phd-pdm\python.exe
# C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\python.exe
# InformationÂ : impossible de trouver "#".
# InformationÂ : impossible de trouver "Windows".
